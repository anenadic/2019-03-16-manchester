# %% [markdown]
# # Data Carpentry Pilot for Medicine Undergrad Students
#
# Website: http://bit.ly/2TIK21Q (or http://anenadic.github.io/2019-03-16-manchester )
#
# Where: Manchester Biomedical Research Centre, University of Manchester
#
# When: March 16, 2019
#
# Instructors: Raniere Silva
#
# Helpers: Aleks Nenadic, Gerard Capes, Niall Beard
#
# Data: http://bit.ly/dc-medicine-2019 (Please download and uncompress)

# %% [markdown]
# To start Jupyter Notebook:
#
# Windows, go to start menu and look for Jupyter.
#
# macOS and Linux, open an terminal and type "jupyter notebook" no quotes.

# %%
2 * 2
# Out:
# 4

# %%
number_of_chromosomes = 23

# %%
number_of_chromosomes
# Out:
# 23

# %%
number_of_chromosomes
# Out:
# 23

# %%
university_name = "University of Manchester"

# %%
university_name
# Out:
# 'University of Manchester'

# %%
another_university_name = "University of Liverpool"

# %%
another_university_name
# Out:
# 'University of Liverpool'

# %%
len(university_name)
# Out:
# 24

# %%
len(another_university_name)
# Out:
# 23

# %%
len(number_of_chromosomes)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-ef90037d8d28> in <module>()
# ----> 1 len(number_of_chromosomes)
#
# TypeError: object of type 'int' has no len()

# %%
type(number_of_chromosomes)
# Out:
# int

# %%
type(university_name)
# Out:
# str

# %%
# ?len

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(...)
#  |      S.__format__(format_spec) -> str
#  |
#  |      Return a formatted version of S as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
university_name.lower()
# Out:
# 'university of manchester'

# %%
university_name
# Out:
# 'University of Manchester'

# %%
university_name.upper()
# Out:
# 'UNIVERSITY OF MANCHESTER'

# %%
university_name.split()
# Out:
# ['University', 'of', 'Manchester']

# %%
university_name
# Out:
# 'University of Manchester'

# %%
university_words = university_name.split()

# %%
university_words
# Out:
# ['University', 'of', 'Manchester']

# %% [markdown]
# *Exercise*
#
# What the type of `university_words`? And list two functions associated to that type?

# %%
type(university_words)
# Out:
# list

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list() -> new empty list
#  |  list(iterable) -> new list initialized from iterable's items
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
# ...

# %%
university_words
# Out:
# ['University', 'of', 'Manchester']

# %%
university_words.sort()

# %%
university_words
# Out:
# ['Manchester', 'University', 'of']

# %%
university_words.count()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-c464bea6a66a> in <module>()
# ----> 1 university_words.count()
#
# TypeError: count() takes exactly one argument (0 given)

# %%
university_words.count("of")
# Out:
# 1

# %%
university_words.count("Liverpool")
# Out:
# 0

# %%
def fahr_to_celsius(temp):
    return ((temp - 32) * (5/9))

# %%
fahr_to_celsius(72)
# Out:
# 22.22222222222222

# %%
fahr_to_celsius(44)
# Out:
# 6.666666666666667

# %% [markdown]
# *Exercise*
#
# 1. Create a funcion that converts ounces to grams.
#
# 2. Create a function that converts pounds to ounces.
#
# 3. Create a function that converts pounds to grams using the previous two functions.

# %%
def ounces_to_grams(ounces):
    """Convert ounces to grams. Note that we use an approximation."""
    return ounces * 28  # This is the information that I found online

# %%
ounces_to_grams(1)
# Out:
# 28

# %%
# ?ounces_to_grams

# %%
help(ounces_to_grams)
# Out:
# Help on function ounces_to_grams in module __main__:
#
# ounces_to_grams(ounces)
#     Convert ounces to grams. Note that we use an approximation.

# %%
def pounds_to_ounces(pounds):
    """Covert pounds to ounces."""
    return 16 * pounds

# %%
pounds_to_ounces(1)
# Out:
# 16

# %%
# 2.5 pounds to grams

pounds_in_ounces = pounds_to_ounces(2.5)
pounds_in_grams = ounces_to_grams(pounds_in_ounces)
pounds_in_grams
# Out:
# 1120.0

# %%
pounds_in_grams = ounces_to_grams(pounds_to_ounces(2.5))
pounds_in_grams
# Out:
# 1120.0

# %%
def pounds_to_grams(pounds):
    """Convert pounds to grams."""
    return ounces_to_grams(pounds_to_ounces(pounds))

# %%
pounds_to_grams(2.5)
# Out:
# 1120.0

# %%
def pounds_to_grams(pounds):
    """Convert pounds to grams."""
    return ounces_to_grams(
        pounds_to_ounces(pounds)
    )

# %%
pounds_to_grams(2.5)
# Out:
# 1120.0

# %%
import pandas

# %%
import pandas as pd

# %%
pd.read_csv("data/antibiotics-sample.csv")
# Out:
#        SHA  PCT PRACTICE         BNF CODE  \
# 0      Q44  RXA   Y00327  0501011P0AAADAD
# 1      Q44  RXA   Y00327  0501011P0AAAJAJ
# 2      Q44  RXA   Y00327  0501012G0AAAAAA
# 3      Q44  RXA   Y00327  0501013B0AAAAAA
# 4      Q44  RXA   Y04664  0501011P0AAADAD
# 5      Q44  RXA   Y04664  0501011P0AAAJAJ
# 6      Q44  RXA   Y04664  0501012G0AAAAAA
# 7      Q44  RY7   N85638  0501011P0AAADAD
# 8      Q44  RY7   N85638  0501011P0AAAJAJ
# 9      Q44  RY7   N85638  0501012G0AAAAAA
# 10     Q44  RY7   N85638  0501013B0AAAAAA
# 11     Q44  RY7   N85645  0501011P0AAADAD
# 12     Q44  RY7   N85645  0501011P0AAAJAJ
# 13     Q44  RY7   N85645  0501012G0AAAAAA
# 14     Q44  RY7   N85645  0501013B0AAAAAA
# 15     Q44  RY7   N85647  0501011P0AAAJAJ
# 16     Q44  RY7   Y04397  0501011P0AAADAD
# 17     Q44  01C   N81002  0501011P0AAADAD
# 18     Q44  01C   N81002  0501011P0AAAJAJ
# 19     Q44  01C   N81013  0501011P0AAAJAJ
# 20     Q44  01C   N81013  0501012G0AAAAAA
# ...

# %%
import io

# %%
import os

# %%
os.getcwd()
# Out:
# '/tmp/data-carpentry-medicie-undergrad'

# %%
pd.read_csv("data/missing-file.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-69-4663bff27d6b> in <module>()
# ----> 1 pd.read_csv("data/missing-file.csv")
#
# ~/anaconda3/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
# ...

# %%
os.chdir("data")

# %%
os.getcwd()
# Out:
# '/tmp/data-carpentry-medicie-undergrad/data'

# %%
os.chdir("..")

# %%
os.getcwd()
# Out:
# '/tmp/data-carpentry-medicie-undergrad'

# %%
os.pardir
# Out:
# '..'

# %%
os.sep
# Out:
# '/'

# %%
pd.read_csv("data/antibiotics-sample.csv")
# Out:
#        SHA  PCT PRACTICE         BNF CODE  \
# 0      Q44  RXA   Y00327  0501011P0AAADAD
# 1      Q44  RXA   Y00327  0501011P0AAAJAJ
# 2      Q44  RXA   Y00327  0501012G0AAAAAA
# 3      Q44  RXA   Y00327  0501013B0AAAAAA
# 4      Q44  RXA   Y04664  0501011P0AAADAD
# 5      Q44  RXA   Y04664  0501011P0AAAJAJ
# 6      Q44  RXA   Y04664  0501012G0AAAAAA
# 7      Q44  RY7   N85638  0501011P0AAADAD
# 8      Q44  RY7   N85638  0501011P0AAAJAJ
# 9      Q44  RY7   N85638  0501012G0AAAAAA
# 10     Q44  RY7   N85638  0501013B0AAAAAA
# 11     Q44  RY7   N85645  0501011P0AAADAD
# 12     Q44  RY7   N85645  0501011P0AAAJAJ
# 13     Q44  RY7   N85645  0501012G0AAAAAA
# 14     Q44  RY7   N85645  0501013B0AAAAAA
# 15     Q44  RY7   N85647  0501011P0AAAJAJ
# 16     Q44  RY7   Y04397  0501011P0AAADAD
# 17     Q44  01C   N81002  0501011P0AAADAD
# 18     Q44  01C   N81002  0501011P0AAAJAJ
# 19     Q44  01C   N81013  0501011P0AAAJAJ
# 20     Q44  01C   N81013  0501012G0AAAAAA
# ...

# %%
sample = pd.read_csv("data/antibiotics-sample.csv")

# %%
sample
# Out:
#        SHA  PCT PRACTICE         BNF CODE  \
# 0      Q44  RXA   Y00327  0501011P0AAADAD
# 1      Q44  RXA   Y00327  0501011P0AAAJAJ
# 2      Q44  RXA   Y00327  0501012G0AAAAAA
# 3      Q44  RXA   Y00327  0501013B0AAAAAA
# 4      Q44  RXA   Y04664  0501011P0AAADAD
# 5      Q44  RXA   Y04664  0501011P0AAAJAJ
# 6      Q44  RXA   Y04664  0501012G0AAAAAA
# 7      Q44  RY7   N85638  0501011P0AAADAD
# 8      Q44  RY7   N85638  0501011P0AAAJAJ
# 9      Q44  RY7   N85638  0501012G0AAAAAA
# 10     Q44  RY7   N85638  0501013B0AAAAAA
# 11     Q44  RY7   N85645  0501011P0AAADAD
# 12     Q44  RY7   N85645  0501011P0AAAJAJ
# 13     Q44  RY7   N85645  0501012G0AAAAAA
# 14     Q44  RY7   N85645  0501013B0AAAAAA
# 15     Q44  RY7   N85647  0501011P0AAAJAJ
# 16     Q44  RY7   Y04397  0501011P0AAADAD
# 17     Q44  01C   N81002  0501011P0AAADAD
# 18     Q44  01C   N81002  0501011P0AAAJAJ
# 19     Q44  01C   N81013  0501011P0AAAJAJ
# 20     Q44  01C   N81013  0501012G0AAAAAA
# ...

# %%
sample.shape
# Out:
# (45116, 10)

# %%
sample.dtypes
# Out:
# SHA          object
# PCT          object
# PRACTICE     object
# BNF CODE     object
# BNF NAME     object
# ITEMS         int64
# NIC         float64
# ACT COST    float64
# QUANTITY      int64
# PERIOD        int64
# dtype: object

# %%
sample.columns
# Out:
# Index(['SHA', 'PCT', 'PRACTICE', 'BNF CODE', 'BNF NAME', 'ITEMS', 'NIC',
#        'ACT COST', 'QUANTITY', 'PERIOD'],
#       dtype='object')

# %%
university_words
# Out:
# ['Manchester', 'University', 'of']

# %%
university_words[0]
# Out:
# 'Manchester'

# %%
sample[["PERIOD"]]  # Note double []
# Out:
#        PERIOD
# 0      201808
# 1      201808
# 2      201808
# 3      201808
# 4      201808
# 5      201808
# 6      201808
# 7      201808
# 8      201808
# 9      201808
# 10     201808
# 11     201808
# 12     201808
# 13     201808
# 14     201808
# 15     201808
# 16     201808
# 17     201808
# 18     201808
# 19     201808
# 20     201808
# 21     201808
# 22     201808
# 23     201808
# 24     201808
# 25     201808
# 26     201808
# 27     201808
# 28     201808
# 29     201808
# ...       ...
# 45086  201811
# 45087  201811
# 45088  201811
# 45089  201811
# 45090  201811
# 45091  201811
# 45092  201811
# 45093  201811
# 45094  201811
# 45095  201811
# 45096  201811
# 45097  201811
# 45098  201811
# 45099  201811
# 45100  201811
# 45101  201811
# 45102  201811
# 45103  201811
# 45104  201811
# 45105  201811
# 45106  201811
# 45107  201811
# 45108  201811
# 45109  201811
# 45110  201811
# 45111  201811
# 45112  201811
# 45113  201811
# 45114  201811
# 45115  201811
#
# ...

# %%
sample["PERIOD"]  # Single [
# Out:
# 0        201808
# 1        201808
# 2        201808
# 3        201808
# 4        201808
# 5        201808
# 6        201808
# 7        201808
# 8        201808
# 9        201808
# 10       201808
# 11       201808
# 12       201808
# 13       201808
# 14       201808
# 15       201808
# 16       201808
# 17       201808
# 18       201808
# 19       201808
# 20       201808
# 21       201808
# 22       201808
# 23       201808
# 24       201808
# 25       201808
# 26       201808
# 27       201808
# 28       201808
# 29       201808
#           ...
# 45086    201811
# 45087    201811
# 45088    201811
# 45089    201811
# 45090    201811
# 45091    201811
# 45092    201811
# 45093    201811
# 45094    201811
# 45095    201811
# 45096    201811
# 45097    201811
# 45098    201811
# 45099    201811
# 45100    201811
# 45101    201811
# 45102    201811
# 45103    201811
# 45104    201811
# 45105    201811
# 45106    201811
# 45107    201811
# 45108    201811
# 45109    201811
# ...

# %%
sample[ ["PERIOD", "SHA"] ]
# Out:
#        PERIOD  SHA
# 0      201808  Q44
# 1      201808  Q44
# 2      201808  Q44
# 3      201808  Q44
# 4      201808  Q44
# 5      201808  Q44
# 6      201808  Q44
# 7      201808  Q44
# 8      201808  Q44
# 9      201808  Q44
# 10     201808  Q44
# 11     201808  Q44
# 12     201808  Q44
# 13     201808  Q44
# 14     201808  Q44
# 15     201808  Q44
# 16     201808  Q44
# 17     201808  Q44
# 18     201808  Q44
# 19     201808  Q44
# 20     201808  Q44
# 21     201808  Q44
# 22     201808  Q44
# 23     201808  Q44
# 24     201808  Q44
# 25     201808  Q44
# 26     201808  Q44
# 27     201808  Q44
# 28     201808  Q44
# 29     201808  Q44
# ...       ...  ...
# 45086  201811  Q70
# 45087  201811  Q70
# 45088  201811  Q70
# 45089  201811  Q70
# 45090  201811  Q70
# 45091  201811  Q70
# 45092  201811  Q70
# 45093  201811  Q70
# 45094  201811  Q70
# 45095  201811  Q70
# 45096  201811  Q70
# 45097  201811  Q70
# 45098  201811  Q70
# 45099  201811  Q70
# 45100  201811  Q70
# ...

# %%
sample.columns
# Out:
# Index(['SHA', 'PCT', 'PRACTICE', 'BNF CODE', 'BNF NAME', 'ITEMS', 'NIC',
#        'ACT COST', 'QUANTITY', 'PERIOD'],
#       dtype='object')

# %%
sample["PERIOD"].unique()
# Out:
# array([201808, 201811])

# %%
pd.crosstab(sample["BNF NAME"], sample["PERIOD"])
# Out:
# PERIOD                                    201808  201811
# BNF NAME
# Amoxicillin_Cap 250mg                       4211    4446
# Fluclox Sod_Cap 250mg                       6050    5754
# Phenoxymethylpenicillin Pot_Tab 250mg       7451    7422
# Phenoxymethylpenicillin_Soln 125mg/5ml      4201    5581

# %%
crosstab_prescription = pd.crosstab(
    sample["BNF NAME"],
    sample["PERIOD"]
)
crosstab_prescription
# Out:
# PERIOD                                    201808  201811
# BNF NAME
# Amoxicillin_Cap 250mg                       4211    4446
# Fluclox Sod_Cap 250mg                       6050    5754
# Phenoxymethylpenicillin Pot_Tab 250mg       7451    7422
# Phenoxymethylpenicillin_Soln 125mg/5ml      4201    5581

# %%
crosstab_prescription.plot()

# %%
# %matplotlib inline

# %%
crosstab_prescription.plot()

# %%
crosstab_prescription.plot(
    kind="bar"
)

# %%
crosstab_prescription.plot(
    kind="bar"
)

# %% [markdown]
# **Exercise**
#
# Have a look at the documentation of `pd.crosstab`. What are the other arguments that it accept?
#
# Use extra arguments to answer (1) which antibiotic is responsible for most of the budget and (2) which antibiotic most dispensed.

# %%
# ?pd.crosstab

# %%
pd.crosstab(
    sample["BNF NAME"],
    sample["PERIOD"],
    values=sample["ACT COST"],
    aggfunc=sum
)
# Out:
# PERIOD                                       201808     201811
# BNF NAME
# Amoxicillin_Cap 250mg                      12392.84   14985.16
# Fluclox Sod_Cap 250mg                      34830.94   23455.80
# Phenoxymethylpenicillin Pot_Tab 250mg     237033.32  243858.33
# Phenoxymethylpenicillin_Soln 125mg/5ml    183971.17  227588.30

# %%
pd.crosstab(
    sample["BNF NAME"],
    sample["PERIOD"],
    values=sample["ACT COST"],
    aggfunc=sum
).plot(
    kind="bar"
)

# %%
pd.crosstab(
    sample["BNF NAME"],
    sample["PERIOD"],
    values=sample["ITEMS"],
    aggfunc=sum
).plot(
    kind="bar"
)

# %% [markdown]
# *Exercise*
#
# Read the file `data/antibiotics.csv` and create a similar visualisation using `crosstab`.

# %%
data = pd.read_csv("data/antibiotics.csv")

pd.crosstab(
    data["BNF NAME"],
    data["PERIOD"],
    values=data["ITEMS"],
    aggfunc=sum
).plot(
    kind="bar"
)

# %%
sample.loc[0, :]
# Out:
# SHA                                              Q44
# PCT                                              RXA
# PRACTICE                                      Y00327
# BNF CODE                             0501011P0AAADAD
# BNF NAME    Phenoxymethylpenicillin_Soln 125mg/5ml
# ITEMS                                             15
# NIC                                           223.86
# ACT COST                                       208.1
# QUANTITY                                        2600
# PERIOD                                        201808
# Name: 0, dtype: object

# %%
sample.loc[[0], :]
# Out:
#    SHA  PCT PRACTICE         BNF CODE  \
# 0  Q44  RXA   Y00327  0501011P0AAADAD
#
#                                    BNF NAME  ITEMS     NIC  ACT COST  \
# 0  Phenoxymethylpenicillin_Soln 125mg/5ml       15  223.86     208.1
#
#    QUANTITY  PERIOD
# 0      2600  201808

# %%
sample.loc[
    [1, 2, 3],
    :
]
# Out:
#    SHA  PCT PRACTICE         BNF CODE  \
# 1  Q44  RXA   Y00327  0501011P0AAAJAJ
# 2  Q44  RXA   Y00327  0501012G0AAAAAA
# 3  Q44  RXA   Y00327  0501013B0AAAAAA
#
#                                    BNF NAME  ITEMS    NIC  ACT COST  QUANTITY  \
# 1  Phenoxymethylpenicillin Pot_Tab 250mg        25  57.16     55.29      1800
# 2  Fluclox Sod_Cap 250mg                         3   3.18      3.09        76
# 3  Amoxicillin_Cap 250mg                         2   1.66      1.57        42
#
#    PERIOD
# 1  201808
# 2  201808
# 3  201808

# %%
sample.loc[
    [1, 2, 3],
    ["PRACTICE", "BNF NAME"]
]
# Out:
#   PRACTICE                                  BNF NAME
# 1   Y00327  Phenoxymethylpenicillin Pot_Tab 250mg
# 2   Y00327  Fluclox Sod_Cap 250mg
# 3   Y00327  Amoxicillin_Cap 250mg

# %%
small_sample = sample.head(10)

# %%
small_sample
# Out:
#    SHA  PCT PRACTICE         BNF CODE  \
# 0  Q44  RXA   Y00327  0501011P0AAADAD
# 1  Q44  RXA   Y00327  0501011P0AAAJAJ
# 2  Q44  RXA   Y00327  0501012G0AAAAAA
# 3  Q44  RXA   Y00327  0501013B0AAAAAA
# 4  Q44  RXA   Y04664  0501011P0AAADAD
# 5  Q44  RXA   Y04664  0501011P0AAAJAJ
# 6  Q44  RXA   Y04664  0501012G0AAAAAA
# 7  Q44  RY7   N85638  0501011P0AAADAD
# 8  Q44  RY7   N85638  0501011P0AAAJAJ
# 9  Q44  RY7   N85638  0501012G0AAAAAA
#
#                                    BNF NAME  ITEMS     NIC  ACT COST  \
# 0  Phenoxymethylpenicillin_Soln 125mg/5ml       15  223.86    208.10
# 1  Phenoxymethylpenicillin Pot_Tab 250mg        25   57.16     55.29
# 2  Fluclox Sod_Cap 250mg                         3    3.18      3.09
# 3  Amoxicillin_Cap 250mg                         2    1.66      1.57
# 4  Phenoxymethylpenicillin_Soln 125mg/5ml        1    8.61      8.01
# 5  Phenoxymethylpenicillin Pot_Tab 250mg        10   25.67     24.36
# ...

# %%
small_sample["PRACTICE"].unique()
# Out:
# array(['Y00327', 'Y04664', 'N85638'], dtype=object)

# %%
small_sample.tail(6).head(3)
# Out:
#    SHA  PCT PRACTICE         BNF CODE  \
# 4  Q44  RXA   Y04664  0501011P0AAADAD
# 5  Q44  RXA   Y04664  0501011P0AAAJAJ
# 6  Q44  RXA   Y04664  0501012G0AAAAAA
#
#                                    BNF NAME  ITEMS    NIC  ACT COST  QUANTITY  \
# 4  Phenoxymethylpenicillin_Soln 125mg/5ml        1   8.61      8.01       100
# 5  Phenoxymethylpenicillin Pot_Tab 250mg        10  25.67     24.36       808
# 6  Fluclox Sod_Cap 250mg                         2   2.34      2.20        56
#
#    PERIOD
# 4  201808
# 5  201808
# 6  201808

# %%
small_sample.loc[
    [
        False,
        False,
        False,
        False,
        True,
        True,
        True,
        False,
        False,
        False
    ],
    :
]
# Out:
#    SHA  PCT PRACTICE         BNF CODE  \
# 4  Q44  RXA   Y04664  0501011P0AAADAD
# 5  Q44  RXA   Y04664  0501011P0AAAJAJ
# 6  Q44  RXA   Y04664  0501012G0AAAAAA
#
#                                    BNF NAME  ITEMS    NIC  ACT COST  QUANTITY  \
# 4  Phenoxymethylpenicillin_Soln 125mg/5ml        1   8.61      8.01       100
# 5  Phenoxymethylpenicillin Pot_Tab 250mg        10  25.67     24.36       808
# 6  Fluclox Sod_Cap 250mg                         2   2.34      2.20        56
#
#    PERIOD
# 4  201808
# 5  201808
# 6  201808

# %%
"a" == "b"
# Out:
# False

# %%
"a"  == "a"
# Out:
# True

# %%
10 < 9
# Out:
# False

# %%
10 > 9
# Out:
# True

# %%
10 >= 9
# Out:
# True

# %%
10 <= 9
# Out:
# False

# %%
small_sample["PRACTICE"] == "Y04664"
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8    False
# 9    False
# Name: PRACTICE, dtype: bool

# %%
small_sample.loc[
    small_sample["PRACTICE"] == "Y04664",
    :
]
# Out:
#    SHA  PCT PRACTICE         BNF CODE  \
# 4  Q44  RXA   Y04664  0501011P0AAADAD
# 5  Q44  RXA   Y04664  0501011P0AAAJAJ
# 6  Q44  RXA   Y04664  0501012G0AAAAAA
#
#                                    BNF NAME  ITEMS    NIC  ACT COST  QUANTITY  \
# 4  Phenoxymethylpenicillin_Soln 125mg/5ml        1   8.61      8.01       100
# 5  Phenoxymethylpenicillin Pot_Tab 250mg        10  25.67     24.36       808
# 6  Fluclox Sod_Cap 250mg                         2   2.34      2.20        56
#
#    PERIOD
# 4  201808
# 5  201808
# 6  201808

# %% [markdown]
# **Exercise**
#
# How many prescriptions do we have from `Y04664` in `data/antibiotics.csv`?

# %%
rows_from_y04664 = data.loc[
    data["PRACTICE"] == "Y04664",
    :
]
rows_from_y04664
# Out:
#         SHA  PCT PRACTICE         BNF CODE  \
# 49      Q44  RXA   Y04664  0501011P0AAADAD
# 50      Q44  RXA   Y04664  0501011P0AAAJAJ
# 51      Q44  RXA   Y04664  0501011P0AAASAS
# 52      Q44  RXA   Y04664  0501012G0AAAAAA
# 53      Q44  RXA   Y04664  0501012G0AAABAB
# 54      Q44  RXA   Y04664  0501012G0AAAGAG
# 55      Q44  RXA   Y04664  0501013B0AAABAB
# 56      Q44  RXA   Y04664  0501013B0AAAKAK
# 57      Q44  RXA   Y04664  0501013B0AAASAS
# 58      Q44  RXA   Y04664  0501013B0AAATAT
# 59      Q44  RXA   Y04664  0501013K0AAAAAA
# 60      Q44  RXA   Y04664  0501013K0AAAGAG
# 61      Q44  RXA   Y04664  0501013K0AAAJAJ
# 62      Q44  RXA   Y04664  0501021L0AAAAAA
# 63      Q44  RXA   Y04664  0501021L0AAABAB
# 64      Q44  RXA   Y04664  0501021L0AAAHAH
# 65      Q44  RXA   Y04664  0501030I0AAABAB
# 66      Q44  RXA   Y04664  0501030L0AAABAB
# 67      Q44  RXA   Y04664  0501030L0BBABAB
# 68      Q44  RXA   Y04664  0501030T0AAAJAJ
# 69      Q44  RXA   Y04664  0501030Z0AAAAAA
# ...

# %%
rows_from_y04664.shape
# Out:
# (75, 10)

# %%
rows_from_y04664.shape[0]
# Out:
# 75

# %%
# Bolean logic
#
# AND is &
#
# OR is |

# %%
True & True
# Out:
# True

# %%
True & False
# Out:
# False

# %%
False & True
# Out:
# False

# %%
False & False
# Out:
# False

# %%
True | True
# Out:
# True

# %%
True | False
# Out:
# True

# %%
False | True
# Out:
# True

# %%
False | False
# Out:
# False

# %%
university_name
# Out:
# 'University of Manchester'

# %%
(university_name == "University of Liverpool") | (university_name == "University of Manchester")
# Out:
# True

# %%
university_name == "University of Liverpool" | university_name == "University of Manchester"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-8bdf11c29a67> in <module>()
# ----> 1 university_name == "University of Liverpool" | university_name == "University of Manchester"
#
# TypeError: unsupported operand type(s) for |: 'str' and 'str'

# %% [markdown]
# **Exercise**
#
# How many prescriptions do we have from `Y04664` or `N85638` in `data/antibiotics.csv`?

# %%
data.loc[
    (data["PRACTICE"] == "Y04664") | (data["PRACTICE"] == "N85638"),
    :
]
# Out:
#         SHA  PCT PRACTICE         BNF CODE  \
# 49      Q44  RXA   Y04664  0501011P0AAADAD
# 50      Q44  RXA   Y04664  0501011P0AAAJAJ
# 51      Q44  RXA   Y04664  0501011P0AAASAS
# 52      Q44  RXA   Y04664  0501012G0AAAAAA
# 53      Q44  RXA   Y04664  0501012G0AAABAB
# 54      Q44  RXA   Y04664  0501012G0AAAGAG
# 55      Q44  RXA   Y04664  0501013B0AAABAB
# 56      Q44  RXA   Y04664  0501013B0AAAKAK
# 57      Q44  RXA   Y04664  0501013B0AAASAS
# 58      Q44  RXA   Y04664  0501013B0AAATAT
# 59      Q44  RXA   Y04664  0501013K0AAAAAA
# 60      Q44  RXA   Y04664  0501013K0AAAGAG
# 61      Q44  RXA   Y04664  0501013K0AAAJAJ
# 62      Q44  RXA   Y04664  0501021L0AAAAAA
# 63      Q44  RXA   Y04664  0501021L0AAABAB
# 64      Q44  RXA   Y04664  0501021L0AAAHAH
# 65      Q44  RXA   Y04664  0501030I0AAABAB
# 66      Q44  RXA   Y04664  0501030L0AAABAB
# 67      Q44  RXA   Y04664  0501030L0BBABAB
# 68      Q44  RXA   Y04664  0501030T0AAAJAJ
# 69      Q44  RXA   Y04664  0501030Z0AAAAAA
# ...

# %%
data.loc[
    (data["PRACTICE"] == "Y04664") | (data["PRACTICE"] == "N85638"),
    :
].shape[0]
# Out:
# 176

# %% [markdown]
# **Exercise**
#
# Which practice prescribe "Fluclox Sod_Cap 250mg"?

# %%
data.loc[
    data["BNF NAME"] == "Fluclox Sod_Cap 250mg",
    :
]
# Out:
# Empty DataFrame
# Columns: [SHA, PCT, PRACTICE, BNF CODE, BNF NAME, ITEMS, NIC, ACT COST, QUANTITY, PERIOD]
# Index: []

# %%
data["BNF NAME"].unique()
# Out:
# array(['Phenoxymethylpenicillin_Soln 125mg/5ml  ',
#        'Phenoxymethylpenicillin_Soln 250mg/5ml  ',
#        'Phenoxymethylpenicillin Pot_Tab 250mg   ',
#        'Phenoxymethylpenicillin_Soln 125mg/5mlSF',
#        'Phenoxymethylpenicillin_Soln 250mg/5mlSF',
#        'Fluclox Sod_Cap 250mg                   ',
#        'Fluclox Sod_Cap 500mg                   ',
#        'Fluclox Sod_Oral Soln 125mg/5ml         ',
#        'Fluclox Sod_Oral Soln 250mg/5ml         ',
#        'Fluclox Sod_Oral Soln 125mg/5ml S/F     ',
#        'Fluclox Sod_Oral Soln 250mg/5ml S/F     ',
#        'Amoxicillin_Cap 250mg                   ',
#        'Amoxicillin_Cap 500mg                   ',
#        'Amoxicillin_Oral Susp 125mg/5ml         ',
#        'Amoxicillin_Oral Susp 250mg/5ml         ',
#        'Amoxicillin_Oral Susp 125mg/5ml S/F     ',
#        'Amoxicillin_Oral Susp 250mg/5ml S/F     ',
#        'Co-Amoxiclav_Tab 250mg/125mg            ',
# ...

# %%
data.loc[
    data["BNF NAME"] == 'Fluclox Sod_Cap 250mg                   ',
    :
]
# Out:
#         SHA  PCT PRACTICE         BNF CODE  \
# 5       Q44  RXA   Y00327  0501012G0AAAAAA
# 52      Q44  RXA   Y04664  0501012G0AAAAAA
# 95      Q44  RY7   N85638  0501012G0AAAAAA
# 150     Q44  RY7   N85645  0501012G0AAAAAA
# 262     Q44  01C   N81013  0501012G0AAAAAA
# 299     Q44  01C   N81021  0501012G0AAAAAA
# 341     Q44  01C   N81022  0501012G0AAAAAA
# 384     Q44  01C   N81026  0501012G0AAAAAA
# 426     Q44  01C   N81027  0501012G0AAAAAA
# 480     Q44  01C   N81029  0501012G0AAAAAA
# 529     Q44  01C   N81033  0501012G0AAAAAA
# 577     Q44  01C   N81042  0501012G0AAAAAA
# 616     Q44  01C   N81049  0501012G0AAAAAA
# 655     Q44  01C   N81052  0501012G0AAAAAA
# 710     Q44  01C   N81062  0501012G0AAAAAA
# 765     Q44  01C   N81069  0501012G0AAAAAA
# 793     Q44  01C   N81070  0501012G0AAAAAA
# 849     Q44  01C   N81073  0501012G0AAAAAA
# 895     Q44  01C   N81077  0501012G0AAAAAA
# 949     Q44  01C   N81085  0501012G0AAAAAA
# 989     Q44  01C   N81086  0501012G0AAAAAA
# ...

# %%
university_name
# Out:
# 'University of Manchester'

# %%
# ?str

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(...)
#  |      S.__format__(format_spec) -> str
#  |
#  |      Return a formatted version of S as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
university_name.find("of")
# Out:
# 11

# %%
university_name.find("Manchester")
# Out:
# 14

# %%
university_name.find("Manchester") >= 0
# Out:
# True

# %%
university_name.find("Liverpool") != -1
# Out:
# False

# %%
help(data["BNF NAME"].str)
# Out:
# Help on StringMethods in module pandas.core.strings object:
#
# class StringMethods(pandas.core.base.NoNewAttributesMixin)
#  |  Vectorized string functions for Series and Index. NAs stay NA unless
#  |  handled otherwise by a particular method. Patterned after Python's string
#  |  methods, with some inspiration from R's stringr package.
#  |
#  |  Examples
#  |  --------
#  |  >>> s.str.split('_')
#  |  >>> s.str.replace('_', '')
#  |
#  |  Method resolution order:
#  |      StringMethods
#  |      pandas.core.base.NoNewAttributesMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __getitem__(self, key)
#  |
#  |  __init__(self, data)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __iter__(self)
#  |
#  |  capitalize lambda self
#  |      Convert strings in the Series/Index to be capitalized.
#  |      Equivalent to :meth:`str.capitalize`.
#  |
#  |      Returns
#  |      -------
# ...

# %%
data["BNF NAME"].str.contains("Fluclox Sod_Cap 250mg")
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5          True
# 6         False
# 7         False
# 8         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 16        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
#           ...
# 620576    False
# 620577    False
# 620578    False
# 620579    False
# 620580    False
# 620581    False
# 620582    False
# 620583    False
# 620584    False
# 620585    False
# 620586    False
# 620587    False
# 620588    False
# 620589    False
# 620590    False
# 620591    False
# 620592    False
# 620593    False
# 620594    False
# 620595    False
# 620596    False
# 620597    False
# 620598    False
# 620599    False
# ...

# %%
data.loc[
    data["BNF NAME"] == "Fluclox Sod_Cap 250mg",
    :
]
# Out:
# Empty DataFrame
# Columns: [SHA, PCT, PRACTICE, BNF CODE, BNF NAME, ITEMS, NIC, ACT COST, QUANTITY, PERIOD]
# Index: []

# %%
fluclox = data.loc[
    data["BNF NAME"].str.contains("Fluclox Sod_Cap 250mg"),
    :
]

# %%
data.loc[
    data["BNF NAME"].str.lower().str.contains("fluclox"),
    :
]
# Out:
#         SHA  PCT PRACTICE         BNF CODE  \
# 5       Q44  RXA   Y00327  0501012G0AAAAAA
# 6       Q44  RXA   Y00327  0501012G0AAABAB
# 7       Q44  RXA   Y00327  0501012G0AAAFAF
# 8       Q44  RXA   Y00327  0501012G0AAAGAG
# 9       Q44  RXA   Y00327  0501012G0AAAPAP
# 10      Q44  RXA   Y00327  0501012G0AAAQAQ
# 42      Q44  RXA   Y04109  0501012G0AAABAB
# 52      Q44  RXA   Y04664  0501012G0AAAAAA
# 53      Q44  RXA   Y04664  0501012G0AAABAB
# 54      Q44  RXA   Y04664  0501012G0AAAGAG
# 95      Q44  RY7   N85638  0501012G0AAAAAA
# 96      Q44  RY7   N85638  0501012G0AAABAB
# 97      Q44  RY7   N85638  0501012G0AAAFAF
# 98      Q44  RY7   N85638  0501012G0AAAGAG
# 99      Q44  RY7   N85638  0501012G0AAAPAP
# 100     Q44  RY7   N85638  0501012G0AAAQAQ
# 150     Q44  RY7   N85645  0501012G0AAAAAA
# 151     Q44  RY7   N85645  0501012G0AAABAB
# 152     Q44  RY7   N85645  0501012G0AAAFAF
# 153     Q44  RY7   N85645  0501012G0AAAGAG
# 154     Q44  RY7   N85645  0501012G0AAAQAQ
# ...

# %% [markdown]
# **Exercise**
#
# > You'll be prescribed at least a six-month course of a combination of antibiotics
# > if you're diagnosed with active pulmonary TB,
# > where your lungs are affected and you have symptoms.
# > The usual treatment is: two antibiotics (isoniazid and rifampicin) for six months.
# >
# > https://www.nhs.uk/conditions/tuberculosis-tb/treatment/
#
# How many practices treated pacients with tuberculosis?

# %%
small_sample
# Out:
#    SHA  PCT PRACTICE         BNF CODE  \
# 0  Q44  RXA   Y00327  0501011P0AAADAD
# 1  Q44  RXA   Y00327  0501011P0AAAJAJ
# 2  Q44  RXA   Y00327  0501012G0AAAAAA
# 3  Q44  RXA   Y00327  0501013B0AAAAAA
# 4  Q44  RXA   Y04664  0501011P0AAADAD
# 5  Q44  RXA   Y04664  0501011P0AAAJAJ
# 6  Q44  RXA   Y04664  0501012G0AAAAAA
# 7  Q44  RY7   N85638  0501011P0AAADAD
# 8  Q44  RY7   N85638  0501011P0AAAJAJ
# 9  Q44  RY7   N85638  0501012G0AAAAAA
#
#                                    BNF NAME  ITEMS     NIC  ACT COST  \
# 0  Phenoxymethylpenicillin_Soln 125mg/5ml       15  223.86    208.10
# 1  Phenoxymethylpenicillin Pot_Tab 250mg        25   57.16     55.29
# 2  Fluclox Sod_Cap 250mg                         3    3.18      3.09
# 3  Amoxicillin_Cap 250mg                         2    1.66      1.57
# 4  Phenoxymethylpenicillin_Soln 125mg/5ml        1    8.61      8.01
# 5  Phenoxymethylpenicillin Pot_Tab 250mg        10   25.67     24.36
# ...

# %%
small_sample.loc[
    small_sample["BNF NAME"].str.lower().str.contains("phenox") & small_sample["BNF NAME"].str.lower().str.contains("fluc"), :
]
# Out:
# Empty DataFrame
# Columns: [SHA, PCT, PRACTICE, BNF CODE, BNF NAME, ITEMS, NIC, ACT COST, QUANTITY, PERIOD]
# Index: []

# %%
practice_with_isoniazid = data.loc[
    data["BNF NAME"].str.lower().str.match("isoniazid"),
    "PRACTICE"
].unique()

# %%
practice_with_rifampicin = data.loc[
    data["BNF NAME"].str.lower().str.match("rifampicin"),
    "PRACTICE"
].unique()

# %%
type(practice_with_isoniazid)
# Out:
# numpy.ndarray

# %%
practice_with_isoniazid = pd.Series(practice_with_isoniazid)

# %%
type(practice_with_isoniazid)
# Out:
# pandas.core.series.Series

# %%
practice_with_rifampicin = pd.Series(practice_with_rifampicin)

# %%
practice_with_isoniazid.isin(practice_with_rifampicin)
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
# 5       True
# 6      False
# 7      False
# 8      False
# 9       True
# 10     False
# 11     False
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21      True
# 22     False
# 23     False
# 24      True
# 25     False
# 26     False
# 27      True
# 28     False
# 29     False
#        ...
# 648    False
# 649    False
# 650    False
# 651    False
# 652    False
# 653     True
# 654    False
# 655    False
# 656    False
# 657    False
# 658    False
# 659     True
# 660    False
# 661     True
# 662     True
# 663    False
# 664    False
# 665     True
# 666     True
# 667     True
# 668     True
# 669    False
# 670    False
# 671    False
# 672    False
# 673     True
# 674    False
# 675     True
# 676     True
# 677    False
# Length: 678, dtype: bool

# %%
practice_with_isoniazid = pd.Series(
    data.loc[
        data["BNF NAME"].str.lower().str.contains("isoniazid"),
        "PRACTICE"
    ].unique()
)
practice_with_rifampicin = pd.Series(
    data.loc[
        data["BNF NAME"].str.lower().str.contains("rifampicin"),
        "PRACTICE"
    ].unique()
)
list_with_tb = practice_with_isoniazid[
    practice_with_isoniazid.isin(
        practice_with_rifampicin
    )
]
# Out:
# 1      Y04031
# 2      Y04032
# 3      Y04033
# 5      A81608
# 9      P83012
# 12     P86007
# 21     P84009
# 24     P84030
# 27     P84072
# 31     P81622
# 37     N83028
# 40     A88004
# 41     A89002
# 42     A82014
# 44     A85005
# 50     C87002
# 53     C88069
# 58     M86014
# 61     M86638
# 64     M81063
# 66     M85069
# 68     M85715
# 70     M88009
# 71     M88022
# 75     M91021
# 76     M91659
# 78     M92024
# 79     M85061
# 86     Y05826
# 87     C81050
#         ...
# 524    G82125
# 526    H81064
# 545    J82069
# 547    J82082
# 549    A83048
# 550    Y02827
# 552    P91026
# 557    A89008
# 558    B86013
# 571    D82054
# 577    F81118
# 583    E82012
# 590    E82603
# 592    E81076
# 594    M83616
# 607    F85030
# 608    F82019
# 613    F84017
# 617    F84031
# 653    H84016
# 659    L84010
# 661    L82041
# 662    Y01127
# 665    G82095
# 666    G82704
# 667    G82016
# 668    G82229
# 673    K81002
# 675    K81006
# 676    J81041
# ...

# %%
data["QUANTITY"]
# Out:
# 0         2600
# 1         1200
# 2         1800
# 3          500
# 4          300
# 5           76
# 6         1388
# 7          600
# 8          400
# 9          400
# 10         900
# 11          42
# 12         513
# 13         300
# 14        1400
# 15         300
# 16        1400
# 17          21
# 18         500
# 19         581
# 20         112
# 21          51
# 22         700
# 23          56
# 24          61
# 25         158
# 26          54
# 27         630
# 28         344
# 29         210
#           ...
# 620576       2
# 620577      15
# 620578     100
# 620579     300
# 620580      56
# 620581      42
# 620582     100
# 620583     192
# 620584       8
# 620585      30
# 620586       3
# 620587      14
# 620588     700
# 620589     358
# 620590     560
# 620591     112
# 620592     200
# 620593      28
# 620594      28
# 620595       1
# 620596     150
# 620597    1030
# 620598      49
# 620599      10
# 620600     182
# 620601     200
# 620602      44
# ...

# %%
data["QUANTITY"].max()
# Out:
# 29400

# %%
data["QUANTITY"].min()
# Out:
# 1

# %%
data["QUANTITY"].mean()
# Out:
# 332.86864290709406

# %%
data["QUANTITY"].sum()
# Out:
# 206580277

# %%
data["QUANTITY"].describe()
# Out:
# count    620606.000000
# mean        332.868643
# std         606.335720
# min           1.000000
# 25%          56.000000
# 50%         138.000000
# 75%         364.000000
# max       29400.000000
# Name: QUANTITY, dtype: float64

# %%
data["PRACTICE"].max()
# Out:
# 'Y06315'

# %%
data["BNF NAME"].shape
# Out:
# (620606,)

# %%
data["BNF NAME"].count()
# Out:
# 620606

# %%
data["BNF NAME"].value_counts()
# Out:
# Fluclox Sod_Cap 500mg                       15672
# Amoxicillin_Cap 500mg                       15570
# Doxycycline Hyclate_Cap 100mg               15445
# Clarithromycin_Tab 500mg                    14980
# Phenoxymethylpenicillin Pot_Tab 250mg       14873
# Nitrofurantoin_Cap 100mg M/R                14729
# Trimethoprim_Tab 200mg                      14691
# Co-Amoxiclav_Tab 500mg/125mg                14670
# Lymecycline_Cap 408mg                       14111
# Metronidazole_Tab 400mg                     14034
# Ciprofloxacin_Tab 500mg                     13370
# Erythromycin_Tab E/C 250mg                  13190
# Amoxicillin_Oral Susp 250mg/5ml S/F         12942
# Trimethoprim_Oral Susp 50mg/5ml S/F         12059
# Trimethoprim_Tab 100mg                      11902
# Fluclox Sod_Cap 250mg                       11804
# Nitrofurantoin_Tab 50mg                     11606
# Azithromycin_Tab 250mg                      11442
# Oxytetracycline_Tab 250mg                   11304
# ...

# %%
data["BNF NAME"].value_counts().head(1)
# Out:
# Fluclox Sod_Cap 500mg                       15672
# Name: BNF NAME, dtype: int64

# %%
data["BNF NAME"].value_counts().tail(1)
# Out:
# Targocid_Inj 200mg Vl + Dil                 1
# Name: BNF NAME, dtype: int64

# %%
bnf_name_counts = data["BNF NAME"].value_counts()
bnf_name_counts[
    bnf_name_counts == 1
]
# Out:
# Tetracycline_Cap 250mg                      1
# Granupas_Gran Sach G/R 4g                   1
# Fluclox_Oral Susp 125mg/5ml                 1
# Acnamino_Cap 100mg M/R (Almus)              1
# Erymax_Cap E/C 250mg                        1
# Ceftazidime Pentahyd_Inj 2g Vl              1
# Co-Trimoxazole_I/V Inf 96mg/ml 5ml Amp      1
# Vancomycin HCl_Liq Spec 125mg/5ml           1
# Rifaximin_Oral Susp 100mg/5ml               1
# Erythromycin_Lactobi I/V Inf 1g Vl          1
# Mycobutin_Cap 150mg                         1
# Amoxicillin Sod_Inj 1g Vl                   1
# Amoxicillin Sod_Inj 250mg Vl                1
# Tobramycin_Oral Soln 40mg/5ml               1
# Penbritin_Cap 250mg                         1
# Ethambutol HCl_Liq Spec 100mg/5ml           1
# Metronidazole_Liq Spec 100mg/5ml            1
# Isoniazid_Liq Spec 400mg/5ml                1
# Metronidazole_I/V Inf 5mg/ml 100ml Btl      1
# Vancocin_I/V Inf 500mg Vl (Dry)             1
# ...

# %% [markdown]
# **Exercise**
#
# `to_csv()` is the function used to write your dataframe into a CSV file.
#
# Use the `to_csv()` function to create a file callend `antibiotics-sample2.csv` that has the data for BNF NAMES in the following list
#
# - Phenoxymethylpenicillin_Soln 125mg/5ml
# - Phenoxymethylpenicillin Pot_Tab 250mg
# - Fluclox Sod_Cap 250mg
# - Amoxicillin_Cap 250mg
#
# **Extra**: write your on function to do this.

# %%
sample2 = data.loc[
    data["BNF NAME"].str.contains("Phenoxymethylpenicillin_Soln 125mg/5ml") |
    data["BNF NAME"].str.contains("Phenoxymethylpenicillin Pot_Tab 250mg") |
    data["BNF NAME"].str.contains("Fluclox Sod_Cap 250mg") |
    data["BNF NAME"].str.contains("Amoxicillin_Cap 250mg"),
    :
]
sample2.to_csv(
    "data/antibiotics-sample2.csv",
    index=False
)

# %%
def create_sample_file():
    """Create sample file called data/antibiotics-sample2.csv"""
    data = pd.read_csv("data/antiobitics.csv")
    sample2 = data.loc[
        data["BNF NAME"].str.contains("Phenoxymethylpenicillin_Soln 125mg/5ml") |
        data["BNF NAME"].str.contains("Phenoxymethylpenicillin Pot_Tab 250mg") |
        data["BNF NAME"].str.contains("Fluclox Sod_Cap 250mg") |
        data["BNF NAME"].str.contains("Amoxicillin_Cap 250mg"),
        :
    ]
    sample2.to_csv(
        "data/antibiotics-sample2.csv",
        index=False
    )

# %%
small_sample
# Out:
#    SHA  PCT PRACTICE         BNF CODE  \
# 0  Q44  RXA   Y00327  0501011P0AAADAD
# 1  Q44  RXA   Y00327  0501011P0AAAJAJ
# 2  Q44  RXA   Y00327  0501012G0AAAAAA
# 3  Q44  RXA   Y00327  0501013B0AAAAAA
# 4  Q44  RXA   Y04664  0501011P0AAADAD
# 5  Q44  RXA   Y04664  0501011P0AAAJAJ
# 6  Q44  RXA   Y04664  0501012G0AAAAAA
# 7  Q44  RY7   N85638  0501011P0AAADAD
# 8  Q44  RY7   N85638  0501011P0AAAJAJ
# 9  Q44  RY7   N85638  0501012G0AAAAAA
#
#                                    BNF NAME  ITEMS     NIC  ACT COST  \
# 0  Phenoxymethylpenicillin_Soln 125mg/5ml       15  223.86    208.10
# 1  Phenoxymethylpenicillin Pot_Tab 250mg        25   57.16     55.29
# 2  Fluclox Sod_Cap 250mg                         3    3.18      3.09
# 3  Amoxicillin_Cap 250mg                         2    1.66      1.57
# 4  Phenoxymethylpenicillin_Soln 125mg/5ml        1    8.61      8.01
# 5  Phenoxymethylpenicillin Pot_Tab 250mg        10   25.67     24.36
# ...

# %%
small_sample["YEAR"] = pd.Series([
    2018,
    2018,
    2018,
    2018,
    2018,
    2018,
    2018,
    2018,
    2018,
    2018
])
small_sample
# Out:
# /home/raniere/anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
#    SHA  PCT PRACTICE         BNF CODE  \
# 0  Q44  RXA   Y00327  0501011P0AAADAD
# 1  Q44  RXA   Y00327  0501011P0AAAJAJ
# 2  Q44  RXA   Y00327  0501012G0AAAAAA
# 3  Q44  RXA   Y00327  0501013B0AAAAAA
# 4  Q44  RXA   Y04664  0501011P0AAADAD
# 5  Q44  RXA   Y04664  0501011P0AAAJAJ
# 6  Q44  RXA   Y04664  0501012G0AAAAAA
# 7  Q44  RY7   N85638  0501011P0AAADAD
# 8  Q44  RY7   N85638  0501011P0AAAJAJ
# 9  Q44  RY7   N85638  0501012G0AAAAAA
#
#                                    BNF NAME  ITEMS     NIC  ACT COST  \
# ...

# %%
sample["BNF NAME LOWER"] = sample["BNF NAME"].str.lower()

# %%
sample
# Out:
#        SHA  PCT PRACTICE         BNF CODE  \
# 0      Q44  RXA   Y00327  0501011P0AAADAD
# 1      Q44  RXA   Y00327  0501011P0AAAJAJ
# 2      Q44  RXA   Y00327  0501012G0AAAAAA
# 3      Q44  RXA   Y00327  0501013B0AAAAAA
# 4      Q44  RXA   Y04664  0501011P0AAADAD
# 5      Q44  RXA   Y04664  0501011P0AAAJAJ
# 6      Q44  RXA   Y04664  0501012G0AAAAAA
# 7      Q44  RY7   N85638  0501011P0AAADAD
# 8      Q44  RY7   N85638  0501011P0AAAJAJ
# 9      Q44  RY7   N85638  0501012G0AAAAAA
# 10     Q44  RY7   N85638  0501013B0AAAAAA
# 11     Q44  RY7   N85645  0501011P0AAADAD
# 12     Q44  RY7   N85645  0501011P0AAAJAJ
# 13     Q44  RY7   N85645  0501012G0AAAAAA
# 14     Q44  RY7   N85645  0501013B0AAAAAA
# 15     Q44  RY7   N85647  0501011P0AAAJAJ
# 16     Q44  RY7   Y04397  0501011P0AAADAD
# 17     Q44  01C   N81002  0501011P0AAADAD
# 18     Q44  01C   N81002  0501011P0AAAJAJ
# 19     Q44  01C   N81013  0501011P0AAAJAJ
# 20     Q44  01C   N81013  0501012G0AAAAAA
# ...

# %%
sample["BNF NAME"].str.lower().str.split()
# Out:
# 0        [phenoxymethylpenicillin_soln, 125mg/5ml]
# 1        [phenoxymethylpenicillin, pot_tab, 250mg]
# 2                        [fluclox, sod_cap, 250mg]
# 3                         [amoxicillin_cap, 250mg]
# 4        [phenoxymethylpenicillin_soln, 125mg/5ml]
# 5        [phenoxymethylpenicillin, pot_tab, 250mg]
# 6                        [fluclox, sod_cap, 250mg]
# 7        [phenoxymethylpenicillin_soln, 125mg/5ml]
# 8        [phenoxymethylpenicillin, pot_tab, 250mg]
# 9                        [fluclox, sod_cap, 250mg]
# 10                        [amoxicillin_cap, 250mg]
# 11       [phenoxymethylpenicillin_soln, 125mg/5ml]
# 12       [phenoxymethylpenicillin, pot_tab, 250mg]
# 13                       [fluclox, sod_cap, 250mg]
# 14                        [amoxicillin_cap, 250mg]
# 15       [phenoxymethylpenicillin, pot_tab, 250mg]
# 16       [phenoxymethylpenicillin_soln, 125mg/5ml]
# 17       [phenoxymethylpenicillin_soln, 125mg/5ml]
# ...

# %%
def extract_drug_name(bnf_name):
    """Exract drug name"""
    return bnf_name.lower().split()[0].split("_")[0]

# %%
data.loc[[1,2,3], :]
# Out:
#    SHA  PCT PRACTICE         BNF CODE  \
# 1  Q44  RXA   Y00327  0501011P0AAAFAF
# 2  Q44  RXA   Y00327  0501011P0AAAJAJ
# 3  Q44  RXA   Y00327  0501011P0AAARAR
#
#                                    BNF NAME  ITEMS     NIC  ACT COST  \
# 1  Phenoxymethylpenicillin_Soln 250mg/5ml        5  107.88    100.26
# 2  Phenoxymethylpenicillin Pot_Tab 250mg        25   57.16     55.29
# 3  Phenoxymethylpenicillin_Soln 125mg/5mlSF      4   39.95     37.15
#
#    QUANTITY  PERIOD
# 1      1200  201808
# 2      1800  201808
# 3       500  201808

# %%
extract_drug_name("Phenoxymethylpenicillin_Soln 125mg/5mlS")
# Out:
# 'phenoxymethylpenicillin'

# %%
"Phenoxymethylpenicillin_Soln 125mg/5mlS".split()
# Out:
# ['Phenoxymethylpenicillin_Soln', '125mg/5mlS']

# %%
"Phenoxymethylpenicillin_Soln 125mg/5mlS".split()[0]
# Out:
# 'Phenoxymethylpenicillin_Soln'

# %%
"Phenoxymethylpenicillin_Soln 125mg/5mlS".split()[0].split("_")
# Out:
# ['Phenoxymethylpenicillin', 'Soln']

# %%
"Phenoxymethylpenicillin_Soln 125mg/5mlS".split()[0].split("_")[0]
# Out:
# 'Phenoxymethylpenicillin'

# %%
sample["BNF NAME"].apply(extract_drug_name)
# Out:
# 0        phenoxymethylpenicillin
# 1        phenoxymethylpenicillin
# 2                        fluclox
# 3                    amoxicillin
# 4        phenoxymethylpenicillin
# 5        phenoxymethylpenicillin
# 6                        fluclox
# 7        phenoxymethylpenicillin
# 8        phenoxymethylpenicillin
# 9                        fluclox
# 10                   amoxicillin
# 11       phenoxymethylpenicillin
# 12       phenoxymethylpenicillin
# 13                       fluclox
# 14                   amoxicillin
# 15       phenoxymethylpenicillin
# 16       phenoxymethylpenicillin
# 17       phenoxymethylpenicillin
# 18       phenoxymethylpenicillin
# 19       phenoxymethylpenicillin
# 20                       fluclox
# 21       phenoxymethylpenicillin
# 22                       fluclox
# 23       phenoxymethylpenicillin
# 24       phenoxymethylpenicillin
# 25                       fluclox
# 26                   amoxicillin
# 27       phenoxymethylpenicillin
# ...

# %%
grouped = data.groupby("PRACTICE")

# %%
grouped

# %%
grouped.get_group("A81001")
# Out:
#         SHA  PCT PRACTICE         BNF CODE  \
# 11428   Q45  00K   A81001  0501011P0AAAJAJ
# 11429   Q45  00K   A81001  0501011P0AAASAS
# 11430   Q45  00K   A81001  0501012G0AAAAAA
# 11431   Q45  00K   A81001  0501012G0AAABAB
# 11432   Q45  00K   A81001  0501013B0AAAAAA
# 11433   Q45  00K   A81001  0501013B0AAABAB
# 11434   Q45  00K   A81001  0501013B0AAASAS
# 11435   Q45  00K   A81001  0501013B0AAATAT
# 11436   Q45  00K   A81001  0501013K0AAAJAJ
# 11437   Q45  00K   A81001  0501013K0BBALAJ
# 11438   Q45  00K   A81001  0501015P0AAABAB
# 11439   Q45  00K   A81001  0501021L0AAADAD
# 11440   Q45  00K   A81001  0501030I0AAAAAA
# 11441   Q45  00K   A81001  0501030I0AAABAB
# 11442   Q45  00K   A81001  0501030L0AAABAB
# 11443   Q45  00K   A81001  0501030T0AAAJAJ
# 11444   Q45  00K   A81001  0501050A0AAAAAA
# 11445   Q45  00K   A81001  0501050A0AAAGAG
# 11446   Q45  00K   A81001  0501050A0BBABAB
# 11447   Q45  00K   A81001  0501050B0AAADAD
# 11448   Q45  00K   A81001  0501050C0AAABAB
# ...

# %%
grouped.size()
# Out:
# PRACTICE
# A81001     63
# A81002    131
# A81004    103
# A81005     94
# A81006    121
# A81007    105
# A81009     98
# A81011     92
# A81012     93
# A81013     96
# A81014     71
# A81016    112
# A81017    121
# A81018    106
# A81019    118
# A81020    104
# A81021    124
# A81022    108
# A81023     78
# A81025     72
# A81026    131
# A81027    103
# A81029     78
# A81030    128
# A81031    116
# A81032    108
# A81033      1
# A81034    125
# A81035     97
# A81036    115
#          ...
# Y06239     16
# Y06240      2
# Y06241      6
# Y06242      2
# Y06243      4
# Y06244      8
# Y06245      8
# Y06247     12
# Y06256      3
# Y06257      5
# Y06258      1
# Y06259     15
# Y06260      1
# Y06263      1
# Y06268     23
# Y06270      3
# Y06271     19
# Y06272      2
# Y06275     32
# Y06276      1
# Y06277     14
# Y06278      1
# Y06281     33
# Y06287     15
# Y06291      3
# Y06295      2
# Y06296      2
# Y06298     12
# Y06311     16
# Y06315      6
# ...

# %%
grouped.size().sort_values()
# Out:
# PRACTICE
# Y03109      1
# Y05688      1
# K81032      1
# Y04282      1
# Y05703      1
# Y05709      1
# Y02730      1
# C84052      1
# Y02680      1
# Y05718      1
# Y04275      1
# Y02670      1
# Y04850      1
# Y02489      1
# Y05742      1
# Y02482      1
# Y02465      1
# Y02439      1
# Y04333      1
# Y02408      1
# Y04345      1
# Y04852      1
# Y05767      1
# Y02902      1
# Y05658      1
# Y03090      1
# Y05561      1
# Y04240      1
# Y03039      1
# Y03038      1
#          ...
# H81133    144
# P83012    144
# K81022    144
# H82017    144
# M89003    145
# H85020    145
# K82073    146
# G85034    147
# J82083    147
# J81056    148
# P81196    148
# A82044    152
# Y01929    152
# E82005    153
# N83028    153
# D81043    154
# Y01008    154
# G82071    155
# D81022    156
# J82069    157
# E82013    157
# F81042    159
# J82155    160
# L83100    161
# M81026    164
# M88004    167
# K83002    167
# M85046    169
# D82044    169
# M85063    195
# ...

# %%
grouped.size().sort_values(ascending=False)
# Out:
# PRACTICE
# M85063    195
# D82044    169
# M85046    169
# K83002    167
# M88004    167
# M81026    164
# L83100    161
# J82155    160
# F81042    159
# E82013    157
# J82069    157
# D81022    156
# G82071    155
# Y01008    154
# D81043    154
# N83028    153
# E82005    153
# Y01929    152
# A82044    152
# P81196    148
# J81056    148
# J82083    147
# G85034    147
# K82073    146
# H85020    145
# M89003    145
# H82017    144
# K81022    144
# P83012    144
# H81133    144
#          ...
# Y03038      1
# Y03039      1
# Y04240      1
# Y05561      1
# Y03090      1
# Y05658      1
# Y02902      1
# Y05767      1
# Y04852      1
# Y04345      1
# Y02408      1
# Y04333      1
# Y02439      1
# Y02465      1
# Y02482      1
# Y05742      1
# Y02489      1
# Y04850      1
# Y02670      1
# Y04275      1
# Y05718      1
# Y02680      1
# C84052      1
# Y02730      1
# Y05709      1
# Y05703      1
# Y04282      1
# K81032      1
# Y05688      1
# Y03109      1
# ...

# %%
grouped.sum()
# Out:
#           ITEMS       NIC  ACT COST  QUANTITY    PERIOD
# PRACTICE
# A81001      419   1923.69   1799.61     16174  12714000
# A81002     1835   8184.61   7670.74     71780  26437037
# A81004      986   7323.46   6822.17     40919  20786386
# A81005      749   4091.72   3828.49     27564  18970099
# A81006     1293   6675.12   6244.69     52791  24418948
# A81007      964   5545.74   5182.14     38896  21189999
# A81009      751   4335.51   4054.71     33633  19777331
# A81011     1077   5209.08   4866.77     42467  18566474
# A81012      622   3579.15   3340.22     25367  18768279
# A81013      606   5508.60   5132.02     25746  19373721
# A81014      311   2531.93   2361.44     13577  14328476
# A81016      868   4456.06   4162.14     37278  22602658
# A81017     1620   8946.50   8357.88     71726  24418960
# A81018     1189   7351.82   6867.67     46358  21391813
# A81019     1029   5984.53   5586.42     50042  23813536
# A81020      847   6258.16   5836.25     32719  20988200
# ...

# %%
grouped.sum().plot(kind="bar")

# %% [markdown]
# *Exercise*
#
# Use `groupby` to know what was the most expensive month/period in our data set?

# %%
grouped = data.groupby("PERIOD")

# %%
grouped.sum()
# Out:
#           ITEMS           NIC      ACT COST   QUANTITY
# PERIOD
# 201808  2375781  1.284641e+07  1.201712e+07   90624475
# 201811  2720152  1.310296e+07  1.223630e+07  115955802

# %%
grouped.sum()["ACT COST"].plot(kind="bar")

# %%
grouped = data.groupby("PRACTICE")
grouped.sum().sort_values("ACT COST", ascending=False)
# Out:
#           ITEMS       NIC  ACT COST  QUANTITY    PERIOD
# PRACTICE
# M85063     4434  29532.91  27573.87    185852  39352851
# B82005     5151  27125.17  25354.89    227346  28455144
# Y01008     4912  25904.68  24211.09    175917  31078657
# M81026     3865  24140.86  22548.60    144475  33096755
# M88004     3541  23542.70  21954.72    155519  33702197
# D81022     3469  20831.46  19711.37    143429  31482303
# G82071     3310  20850.38  19477.93    119396  31280474
# K83002     4245  20820.67  19447.86    151155  33702182
# D82044     3933  20288.06  18966.94    151682  34105798
# J82155     3987  20131.07  18825.32    168803  32289514
# M85046     3276  19847.17  18528.79    144446  34105810
# L83100     3338  19558.50  18245.47    134675  32491325
# Y00192     4033  19420.00  18139.35    181511  28253333
# Y01929     2836  18326.31  17120.92    123518  30675044
# J82069     3060  17803.52  16634.47    117671  31684093
# A82016     3543  17724.35  16578.14    138785  28858766
# ...

# %%
grouped.sum().sort_values(
    "ACT COST",
    ascending=False
)["ACT COST"].head(10).plot(
    kind="bar"
)
